# %%
import cv2
import os
import pandas as pd
import matplotlib.pyplot as plt

from deepface import DeepFace
import pickle
import math

# %% [markdown]
# # Setting

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]

filepath = "C:\\Users\\ksko\\Desktop\\work\\"
src = "C:\\Users\\ksko\\Desktop\\work\\00010.jpg"

total_data = os.listdir(filepath+'w\\')

# %% [markdown]
# filepath 에는 동영상이 들어있는 폴더 전 단계 경로
#
# src에는 src로 비교할 이미지 한개 경로
#
# 최종적으로 total_data에 들어가는 경로가 동영상이 전부 들어있는 폴더입니다.

# %%
total_data[:3]
# Out:
# ['num1_guide.mp4', 'num1_reaction.mp4', 'num1_task1_question.mp4']

# %%
scenario = ['시험공부01','시험공부02','면접01','사랑01','전화01','비지니스01','대화와응답01',
            '의견파악01','관계01','todo','num1','num2']
# 숫자정보01 : num1
# 숫자정보02 : num2
# 할일,부탁할일01 : todo

# %% [markdown]
# 동영상 맨 앞 제목을 scenario list에 적어서 넣어주시면됩니다.
#
# 저의 경우 숫자정보01이 num1_~~~ 로 저장되어 있어 해당부분을 수정하여 넣어둔 상태입니다.
#
# 그러고 나서 아래 코드도 이름 맞춰 넣어주시면 됩니다.

# %%
# 영상 제목들을 넣을 리스트
test01 = []
test02 = []
interview = []
love = []
call = []
business = []
conversation = []
opinion = []
relation = []
todo = []
num1 = []
num2 = []

# 영상 제목들을 추가
for i in range(len(total_data)):
    if total_data[i][:6] == '시험공부01':
        test01.append(total_data[i])
    elif total_data[i][:6] == '시험공부02':
        test02.append(total_data[i])
    elif total_data[i][:2] == '면접':
        interview.append(total_data[i])
    elif total_data[i][:2] == '사랑':
        love.append(total_data[i])
    elif total_data[i][:2] == '전화':
        call.append(total_data[i])
    elif total_data[i][:2] == '비지':
        business.append(total_data[i])
    elif total_data[i][:2] == '대화':
        conversation.append(total_data[i])
    elif total_data[i][:2] == '의견':
        opinion.append(total_data[i])
    elif total_data[i][:2] == '관계':
        relation.append(total_data[i])
    elif total_data[i][:4] == 'todo':
        todo.append(total_data[i])
    elif total_data[i][:4] == 'num1':
        num1.append(total_data[i])
    elif total_data[i][:4] == 'num2':
        num2.append(total_data[i])
#    if total_data[i][:6] == '인사': # 인사가 빠짐!!
#        test01.append(total_data[i])


# 영상의 유사도를 저장하는 리스트
test01_result = []
test02_result = []
interview_result = []
love_result = []
call_result = []
business_result = []
conversation_result = []
opinion_result = []
relation_result = []
todo_result = []
num1_result = []
num2_result = []


# 영상 제목을 넣는 리스트를 묶은 리스트 (이중리스트)
name_list = [test01, test02, interview, love, 
            call, business, conversation, opinion, 
            relation, todo, num1, num2]

# 영상의 유사도를 저장하는 리스트를 묶은 리스트 (이중리스트)
result_list = [test01_result, test02_result, interview_result, love_result,
              call_result, business_result, conversation_result, opinion_result,
              relation_result, todo_result, num1_result, num2_result]

# %%
# list(map(len, (test01, test02, interview, love, call, business, conversation, opinion, relation, todo, num1, num2)))
# 빈거 체크

# %% [markdown]
# # Code

# %%
# 시나리오별로 반복
for i in range(len(scenario)):
    print(f"--- 현재 진행중인 시나리오--- : {scenario[i]}")
    temp_name_list = name_list[i]
    temp_result_list = result_list[i]
    
    # 영상별로 반복
    for name in temp_name_list:
        path = filepath + 'w\\' + name # 여자
        video = cv2.VideoCapture(path)
        if(video.isOpened()):
            print(f"현재 진행중인 영상 : {name}")
        length = video.get(cv2.CAP_PROP_FRAME_COUNT)
        cut = math.floor(length/10) # 구간을 10개로 나눈다
        if cut == 0: # 프레임이 1인경우 0으로 나누게 되어 오류가 남. 제외시키자
            continue
        count = 0
        
        print('영상의 프레임수', length)
        
        # 영상의 프레임별로 반복
        while(video.isOpened()):
            ret, img = video.read() # 다음 프레임 읽기
            
            if (int(video.get(1))%cut==0): # 10개의 구간
                result = DeepFace.verify(img1_path = img, # 유사도 측정
                          img2_path = src,
                          distance_metric = metrics[0]
                )

                count += 1
                print(f'유사도 : {result["distance"]}\r', end='') # 유사도 출력
                # 11번째로 넘어가는 경우 추가하지 않는다.
                if count <= 10:
                    temp_result_list.append(result['distance'])
                else: count -= 1
                
            if video.get(1) >= length : 
                print("                              ", end='')
                print(f"\r나눠진 사진 수 : {count} \n")
                break
# Out:
# --- 현재 진행중인 시나리오--- : 시험공부01
# 현재 진행중인 영상 : 시험공부01_Mission_Complete_Reaction.mp4
# 영상의 프레임수 112.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Mission_Start_Description_En.mp4
# 영상의 프레임수 216.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Mission_Start_Guide_En.mp4
# 영상의 프레임수 53.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Mission_Start_Title.mp4
# 영상의 프레임수 68.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_1_Q1.mp4
# 영상의 프레임수 70.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_1_Reaction_Reaction.mp4
# 영상의 프레임수 84.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_2_Q2.mp4
# 영상의 프레임수 119.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 62.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_3_Q3.mp4
# 영상의 프레임수 79.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 79.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_4_Q4_Reaction.mp4
# 영상의 프레임수 100.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부01_Task_4_Reaction_Reaction.mp4
# 영상의 프레임수 69.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 시험공부02
# 현재 진행중인 영상 : 시험공부02_Mission_Complete_Reaction.mp4
# 영상의 프레임수 122.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Mission_Start_Description_En.mp4
# 영상의 프레임수 176.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Mission_Start_Guide_En.mp4
# 영상의 프레임수 24.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Mission_Start_Title.mp4
# 영상의 프레임수 210.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_1_Q1.mp4
# 영상의 프레임수 47.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_1_Reaction_Reaction.mp4
# 영상의 프레임수 74.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_2_Q2.mp4
# 영상의 프레임수 89.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 24.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_3_Q3.mp4
# 영상의 프레임수 85.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 52.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_4_Q4.mp4
# 영상의 프레임수 65.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 시험공부02_Task_4_Reaction_Reaction.mp4
# 영상의 프레임수 46.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 면접01
# 현재 진행중인 영상 : 면접01_Mission_Complete_Reaction.mp4
# 영상의 프레임수 34.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Mission_Start_Description_En.mp4
# 영상의 프레임수 292.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Mission_Start_Guide_En.mp4
# 영상의 프레임수 60.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Mission_Start_Title.mp4
# 영상의 프레임수 81.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_1_Q1.mp4
# 영상의 프레임수 119.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_1_Reaction_Reaction.mp4
# 영상의 프레임수 93.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_2_Q2.mp4
# 영상의 프레임수 65.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 26.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_3_Q3.mp4
# 영상의 프레임수 138.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 36.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_4_Q4.mp4
# 영상의 프레임수 91.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 면접01_Task_4_Reaction_Reaction.mp4
# 영상의 프레임수 35.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 사랑01
# 현재 진행중인 영상 : 사랑01_Mission_Complete_Reaction.mp4
# 영상의 프레임수 95.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Mission_Start_Description_En.mp4
# 영상의 프레임수 172.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Mission_Start_Guide_En.mp4
# 영상의 프레임수 62.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Mission_Start_Title.mp4
# 영상의 프레임수 267.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_1_Q1.mp4
# 영상의 프레임수 64.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_1_Reaction_Reaction.mp4
# 영상의 프레임수 188.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_2_Q2.mp4
# 영상의 프레임수 69.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 65.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_3_Q3.mp4
# 영상의 프레임수 101.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 101.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_4_Q4.mp4
# 영상의 프레임수 116.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 사랑01_Task_4_Reaction_Reaction.mp4
# 영상의 프레임수 62.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 전화01
# 현재 진행중인 영상 : 전화01_Mission_Complete_Reaction.mp4
# 영상의 프레임수 54.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Mission_Start_Description_En.mp4
# 영상의 프레임수 333.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Mission_Start_Guide_En.mp4
# 영상의 프레임수 40.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Mission_Start_Title.mp4
# 영상의 프레임수 210.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_1_Q1.mp4
# 영상의 프레임수 56.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_1_Reaction_Reaction.mp4
# 영상의 프레임수 64.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_2_Q2.mp4
# 영상의 프레임수 78.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 45.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_3_Q3.mp4
# 영상의 프레임수 135.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 50.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_4_Q4.mp4
# 영상의 프레임수 50.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 전화01_Task_4_Reaction_Reaction.mp4
# 영상의 프레임수 88.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 비지니스01
# 현재 진행중인 영상 : 비지니스01_Mission_Complete_Reaction.mp4
# 영상의 프레임수 57.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Mission_Start_Description_En.mp4
# 영상의 프레임수 83.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Mission_Start_Guide_En.mp4
# 영상의 프레임수 83.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Mission_Start_Title.mp4
# 영상의 프레임수 90.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Task_1_Q1.mp4
# 영상의 프레임수 76.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Task_2_Q2.mp4
# 영상의 프레임수 78.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 27.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Task_3_Q3.mp4
# 영상의 프레임수 84.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 34.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Task_4_Q4.mp4
# 영상의 프레임수 89.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 비지니스01_Task_4_Reaction_Reaction.mp4
# 영상의 프레임수 32.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 대화와응답01
# 현재 진행중인 영상 : 대화와응답01_Mission_Complete_Reaction.mp4
# 영상의 프레임수 137.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Mission_Start_Description_En.mp4
# 영상의 프레임수 230.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Mission_Start_Guide_En.mp4
# 영상의 프레임수 70.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Mission_Start_Title.mp4
# 영상의 프레임수 92.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Task_1_Q1.mp4
# 영상의 프레임수 110.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Task_2_Q2.mp4
# 영상의 프레임수 54.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 89.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Task_3_Q3.mp4
# 영상의 프레임수 437.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 대화와응답01_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 26.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 의견파악01
# 현재 진행중인 영상 : 의견파악01_Mission_Start_Description.mp4
# 영상의 프레임수 146.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Mission_Start_Guide.mp4
# 영상의 프레임수 94.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_1_Q1.mp4
# 영상의 프레임수 124.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_1_Reaction.mp4
# 영상의 프레임수 138.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_2_Q2.mp4
# 영상의 프레임수 173.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_2_Reaction.mp4
# 영상의 프레임수 130.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_3_Q3.mp4
# 영상의 프레임수 139.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_3_Reaction.mp4
# 영상의 프레임수 109.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_4_Q4.mp4
# 영상의 프레임수 156.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 의견파악01_Task_4_Reaction.mp4
# 영상의 프레임수 25.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : 관계01
# 현재 진행중인 영상 : 관계01_Mission_Complete_Reaction.mp4
# 영상의 프레임수 168.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Mission_Start_Description_En.mp4
# 영상의 프레임수 191.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Mission_Start_Guide_En.mp4
# 영상의 프레임수 61.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Mission_Start_Title.mp4
# 영상의 프레임수 149.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_1_Q1.mp4
# 영상의 프레임수 149.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_1_Reaction_Reaction.mp4
# 영상의 프레임수 34.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_2_Q2.mp4
# 영상의 프레임수 63.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_2_Reaction_Reaction.mp4
# 영상의 프레임수 160.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_3_Q3.mp4
# 영상의 프레임수 176.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_3_Reaction_Reaction.mp4
# 영상의 프레임수 50.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_4_Q4.mp4
# 영상의 프레임수 93.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_4_Reaction_Reaction.mp4
# 영상의 프레임수 34.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_5_Q5.mp4
# 영상의 프레임수 87.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : 관계01_Task_5_Reaction_Reaction.mp4
# 영상의 프레임수 42.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : todo
# 현재 진행중인 영상 : todo_description.mp4
# 영상의 프레임수 130.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_guide.mp4
# 영상의 프레임수 107.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_reaction.mp4
# 영상의 프레임수 149.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_task1_question.mp4
# 영상의 프레임수 50.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_task1_reaction.mp4
# 영상의 프레임수 116.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_task2_question.mp4
# 영상의 프레임수 109.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_task2_reaction.mp4
# 영상의 프레임수 41.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_task3_question.mp4
# 영상의 프레임수 92.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : todo_task3_reaction.mp4
# 영상의 프레임수 271.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : num1
# 현재 진행중인 영상 : num1_guide.mp4
# 영상의 프레임수 103.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_reaction.mp4
# 영상의 프레임수 63.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task1_question.mp4
# 영상의 프레임수 68.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task1_reaction.mp4
# 영상의 프레임수 31.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task2_question.mp4
# 영상의 프레임수 220.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task2_reaction.mp4
# 영상의 프레임수 88.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task3_question.mp4
# 영상의 프레임수 153.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task3_reaction.mp4
# 영상의 프레임수 209.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task4_question.mp4
# 영상의 프레임수 121.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task4_reaction.mp4
# 영상의 프레임수 62.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task5_question.mp4
# 영상의 프레임수 62.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_task5_reaction.mp4
# 영상의 프레임수 37.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num1_title.mp4
# 영상의 프레임수 104.0
# 나눠진 사진 수 : 10
#
# --- 현재 진행중인 시나리오--- : num2
# 현재 진행중인 영상 : num2_description.mp4
# 영상의 프레임수 137.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_guide.mp4
# 영상의 프레임수 78.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_reaction.mp4
# 영상의 프레임수 76.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task1_question.mp4
# 영상의 프레임수 157.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task1_reaction.mp4
# 영상의 프레임수 104.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task2_question.mp4
# 영상의 프레임수 51.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task2_reaction.mp4
# 영상의 프레임수 24.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task3_question.mp4
# 영상의 프레임수 101.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task3_reaction.mp4
# 영상의 프레임수 117.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task4_question.mp4
# 영상의 프레임수 65.0
# 나눠진 사진 수 : 10
#
# 현재 진행중인 영상 : num2_task4_reaction.mp4
# 영상의 프레임수 29.0
# 나눠진 사진 수 : 10

# %%
for i in range(len(scenario)):
    pd.Series(result_list[i]).to_csv(filepath + scenario[i] + '.csv', index=False)

# %%
for i in range(len(scenario)):
    print(f"{scenario[i]}의 유사도 평균은 {round(pd.Series(result_list[i]).mean(),2)}, 표준편차는 {round(pd.Series(result_list[i]).std(),2)} 입니다.")
# Out:
# 시험공부01의 유사도 평균은 0.38, 표준편차는 0.15 입니다.
# 시험공부02의 유사도 평균은 0.33, 표준편차는 0.25 입니다.
# 면접01의 유사도 평균은 0.32, 표준편차는 0.25 입니다.
# 사랑01의 유사도 평균은 0.33, 표준편차는 0.25 입니다.
# 전화01의 유사도 평균은 0.32, 표준편차는 0.26 입니다.
# 비지니스01의 유사도 평균은 0.33, 표준편차는 0.25 입니다.
# 대화와응답01의 유사도 평균은 0.17, 표준편차는 0.19 입니다.
# 의견파악01의 유사도 평균은 0.34, 표준편차는 0.26 입니다.
# 관계01의 유사도 평균은 0.29, 표준편차는 0.24 입니다.
# todo의 유사도 평균은 0.34, 표준편차는 0.25 입니다.
# num1의 유사도 평균은 0.34, 표준편차는 0.25 입니다.
# num2의 유사도 평균은 0.28, 표준편차는 0.25 입니다.
